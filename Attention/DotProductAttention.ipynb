# %%
import tensorflow as tf

# %%
class DotProductAttention(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(DotProductAttention, self).__init__(**kwargs)

    def call(self, queries, keys, values, d_k, mask=None):
        scores = tf.matmul(queries, keys, transpose_b=True) / tf.sqrt(d_k)

        # Effectively zeroing entries in softmax
        if mask is not None:
            scores += -1e9 * mask 

        weights = tf.nn.softmax(scores)

        return tf.matmul(weights, values)

# %%
d_k = 64
d_v = 64
batch_size = 64

# %% [markdown]
# ## Encoded Q, K, V in d_k, d_v dimensional embeddings

# %%
input_seq_length = 5

queries = tf.random.normal((batch_size, input_seq_length, d_k))
keys = tf.random.normal((batch_size, input_seq_length, d_k))
values = tf.random.normal((batch_size, input_seq_length, d_v))

# %%
attention = DotProductAttention()

# %%
attention(queries, keys, values, float(d_k))
# Out:
# <tf.Tensor: shape=(64, 5, 64), dtype=float32, numpy=
# array([[[ 3.75479087e-02,  4.72116023e-01, -6.70002759e-01, ...,
#           6.63412809e-01, -2.52603471e-01, -2.19621927e-01],
#         [-3.02511733e-02,  1.93555504e-01, -9.69966292e-01, ...,
#           9.31107283e-01, -2.16214523e-01,  5.26975095e-03],
#         [-3.55486959e-01,  8.85416269e-01, -1.56694031e+00, ...,
#           1.09475648e+00,  3.37226242e-01,  8.43522102e-02],
#         [ 1.45715311e-01,  1.69898242e-01, -4.37818170e-01, ...,
#           7.30177879e-01, -2.84205258e-01, -1.48013800e-01],
#         [ 3.85785073e-01, -3.60571355e-01, -1.58017725e-02, ...,
#           7.51868129e-01, -5.30208945e-01, -1.70763046e-01]],
#
#        [[ 8.44509482e-01,  7.87269831e-01,  6.28012180e-01, ...,
#          -8.55544209e-02,  4.41683620e-01,  1.23979166e-01],
#         [ 3.44490707e-01,  2.38743469e-01,  1.76922619e-01, ...,
#          -3.50720286e-01,  2.88799822e-01, -1.85766384e-01],
#         [ 4.57370162e-01,  6.12573564e-01,  4.18371260e-01, ...,
#          -1.81940347e-02,  4.16616946e-01,  3.74132782e-01],
#         [ 8.45243275e-01,  6.30190969e-01,  5.07141948e-01, ...,
#          -2.22900689e-01,  2.35326767e-01,  1.09228045e-01],
#         [ 1.02781475e+00,  1.37225926e-01,  2.46124759e-01, ...,
#          -8.70825052e-01, -8.03380549e-01, -4.15871829e-01]],
#
#        [[ 1.72141939e-01,  5.25850058e-01, -6.15572214e-01, ...,
#          -7.52999246e-01, -4.96268988e-01, -1.61251813e-01],
#         [-4.40983772e-02,  1.51830339e+00, -8.64006221e-01, ...,
#           1.06948577e-01,  3.95571083e-01,  6.73036695e-01],
#         [ 4.75321889e-01,  1.67840338e+00, -5.94353020e-01, ...,
#           4.07636166e-04,  7.48404622e-01,  3.35348964e-01],
#         [ 1.00142375e-01,  7.12255001e-01, -4.76724505e-01, ...,
#          -3.94849598e-01, -3.76553446e-01, -1.09562129e-01],
#         [ 2.13680863e-01,  1.71003771e+00, -9.22202051e-01, ...,
#          -4.04088557e-01,  3.08625460e-01,  7.15467274e-01]],
#
#        ...,
#
#        [[ 4.97293919e-01,  3.18756282e-01,  3.10236692e-01, ...,
#           1.66738391e+00, -5.08177161e-01,  1.35901666e+00],
#         [ 3.33277166e-01, -2.06862509e-01,  1.11505628e-01, ...,
#           9.49723482e-01,  7.48145461e-01,  4.23593223e-01],
#         [ 5.40108740e-01,  3.27066660e-01,  1.79697111e-01, ...,
#           1.27906334e+00, -1.90031558e-01,  8.92352045e-01],
#         [ 7.69872665e-01,  6.29351199e-01,  4.21532005e-01, ...,
#           1.19461679e+00, -6.36246562e-01, -2.09469512e-01],
#         [ 5.62238157e-01,  5.97582102e-01,  7.40641534e-01, ...,
#           1.28603864e+00,  2.93421030e-01,  8.52781415e-01]],
#
#        [[ 2.02002615e-01, -6.64424479e-01,  2.99796820e-01, ...,
#           2.04432234e-01,  2.07280219e-01,  1.73125178e-01],
#         [-4.53002155e-01, -1.53823316e+00,  3.85802358e-01, ...,
#           1.60619408e-01,  6.48784220e-01,  2.09886163e-01],
#         [-2.80083269e-01, -1.05964959e+00,  4.43734527e-01, ...,
#           5.16713619e-01,  6.40467107e-01,  4.01813775e-01],
#         [-2.27758989e-01, -7.65650511e-01,  1.26737773e-01, ...,
#           1.38663918e-01,  2.94588506e-01,  4.43994850e-02],
#         [-1.32196262e-01, -1.14861798e+00,  5.00478745e-01, ...,
#           4.31216329e-01,  3.56043220e-01,  6.83480442e-01]],
#
#        [[ 1.18534565e-01,  2.52984196e-01, -5.94064116e-01, ...,
#           7.23679066e-01,  4.84306037e-01, -3.05827826e-01],
#         [ 3.13181669e-01,  8.14008057e-01, -4.79548424e-01, ...,
#           5.35290241e-01,  9.83181655e-01, -8.53799582e-02],
#         [-4.29849863e-01, -5.36405206e-01, -2.80323416e-01, ...,
#           5.31522855e-02, -5.72961628e-01,  5.84102809e-01],
#         [-1.36148617e-01, -1.81610823e-01, -8.18710029e-02, ...,
#           3.68071973e-01,  3.02520752e-01,  6.51714206e-02],
#         [-4.37601775e-01, -4.48849797e-01, -1.69853866e-01, ...,
#           2.30856583e-01, -4.30656284e-01,  1.55289388e+00]]],
#       dtype=float32)>
